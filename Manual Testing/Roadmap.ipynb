# %% [markdown]
# ## **✅ Manual Testing + Agile + JIRA Roadmap (BEGINNER-FRIENDLY ORDER)**

# %% [markdown]
# ### **🔰 STEP 1: Understand the Basics of Testing**
#
# > 🧠 Focus: What is testing? Why is it needed?
#
# - What is Software?
#
# - What is Software Testing?
#
# - Why do we need Testing?
#
# - Software Quality
#
# - Project vs Product
#
# - Testing vs Debugging
#
# - Error vs Defect vs Failure vs Bug
#
# - Verification vs Validation
#
# - QA vs QC vs QE
#
# - What causes bugs in software?

# %% [markdown]
# ### **🔰 STEP 2: Learn Development & Testing Life Cycles**
#
# > **🧠 Focus: How projects are built and where testing fits.**
#
# - What is SDLC (Software Development Life Cycle)?
#
#     - Waterfall Model
#
#     - V-Model
#
#     - Spiral Model
#
# - What is STLC (Software Testing Life Cycle)?
#
#     - Requirement Analysis
#
#     - Test Planning
#
#     - Test Case Development
#
#     - Environment Setup
#
#     - Test Execution
#
#     - Test Closure

# %% [markdown]
# ### **🔰 STEP 3: Testing Levels & Types**
#
# > 🧠 Focus: What kinds of testing happen at different stages?
#
# - Levels of Testing:
#
#     - Unit Testing
#
#     - Integration Testing
#
#     - System Testing
#
#     - User Acceptance Testing (UAT)
#
# - Testing Types:
#
#     - Smoke vs Sanity
#
#     - Re-Testing vs Regression
#
#     - Exploratory vs Ad-hoc
#
#     - Functional vs Non-functional
#
#     - GUI, Usability, Compatibility
#
#     - Load, Stress, Performance

# %% [markdown]
# ### **🔰 STEP 4: Manual Testing Techniques**
#
# > **🧠 Focus: How to actually test.**
#
# - Black Box vs White Box vs Grey Box
#
# - Static vs Dynamic Testing
#
# - Test Case Design Techniques:
#
#     - Equivalence Partitioning
#
#     - Boundary Value Analysis
#
#     - Decision Table
#
# - Test Case vs Test Scenario vs Use Case
#
# - Writing Test Cases (Positive & Negative)

# %% [markdown]
# ### **🔰 STEP 5: Test Execution & Defect Management**
#
# > **🧠 Focus: What happens when testing is in progress?**
#
# - Executing Test Cases
#
# - Test Summary Reports
#
# - What is a Defect?
#
# - Defect Life Cycle
#
# - Severity vs Priority
#
# - Bug Reporting (Manual Format)

# %% [markdown]
# ### **🔰 STEP 6: Real-Time Hands-on Practice**
#
# **🧪 Practice:**
#
# - Create test cases for:
#
#     - Login form
#
#     - Registration form
#
#     - E-commerce checkout flow
#
# - Execute them manually
#
# - Log sample bugs in Excel or Google Sheets

# %% [markdown]
# ### **🔰 STEP 7: Learn Agile Testing Approach**
#
# > **🧠 Focus: How modern companies work with Agile.**
#
# - What is Agile?
#
# - What is Scrum?
#
# - Scrum Roles:
#
#     - Product Owner
#
#     - Scrum Master
#
#     - Development Team
#
# - Scrum Ceremonies:
#
#     - Sprint Planning
#
#     - Daily Stand-ups
#
#     - Sprint Review
#
#     - Sprint Retrospective
#
# - Product Backlog vs Sprint Backlog
#
# - What is a User Story?
#
# - Story Points, Acceptance Criteria
#
# - Definition of Ready (DoR) & Done (DoD)

# %% [markdown]
# ### **🔰 STEP 8: Introduction to JIRA**
#
# > 🧠 Focus: Learn the most used tool in companies.
#
# - What is JIRA?
#
# - JIRA Dashboard Overview
#
# - Creating:
#
#     - Epics
#
#     - User Stories
#
#     - Sub-Tasks
#
#     - Bugs
#
# - Assigning Issues
#
# - Workflow Statuses
#
# - Sprint Creation & Management

# %% [markdown]
# ### **🔰 STEP 9: Test Case Management in JIRA (with Zephyr)**
#
# > **🧠 Focus: Manage test cases inside JIRA (real-time flow)**
#
# - What is Zephyr?
#
# - Creating Test Cases in JIRA
#
# - Mapping Test Cases to User Stories
#
# - Creating Test Cycles
#
# - Executing Test Cases
#
# - Generating Reports in Zephyr

# %% [markdown]
# ### **🔰 STEP 10: Final Project for Portfolio**
#
# > **🧪 Task: Pick a mini-project like:**
#
# - E-commerce login → product search → add to cart → checkout
#
# - Create:
#
#     - Test Scenarios
#
#     - Test Cases
#
#     - Execute Tests
#
#     - Log Bugs
#
#     - Use JIRA (Zephyr) for tracking
